# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/user/Downloads/Customer_Data.csv")

# %%
# Display the dataset
df
# Out:
#    CustomerID  Gender  Age       City  Income Purchased
# 0           1    Male   25  Hyderabad   35000       Yes
# 1           2  Female   32  Bengaluru   52000        No
# 2           3    Male   28    Chennai   41000       Yes
# 3           4  Female   45       Pune   65000       Yes
# 4           5    Male   22  Hyderabad   30000        No
# 5           6  Female   38  Bengaluru   58000       Yes
# 6           7    Male   31    Chennai   48000        No
# 7           8  Female   27       Pune   39000       Yes
# 8           9    Male   41  Hyderabad   61000       Yes
# 9          10  Female   35  Bengaluru   55000        No

# %%
# Display first 5 rows
df.head()
# Out:
#    CustomerID  Gender  Age       City  Income Purchased
# 0           1    Male   25  Hyderabad   35000       Yes
# 1           2  Female   32  Bengaluru   52000        No
# 2           3    Male   28    Chennai   41000       Yes
# 3           4  Female   45       Pune   65000       Yes
# 4           5    Male   22  Hyderabad   30000        No

# %%
# Display Dataset Information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  10 non-null     int64
#  1   Gender      10 non-null     str
#  2   Age         10 non-null     int64
#  3   City        10 non-null     str
#  4   Income      10 non-null     int64
#  5   Purchased   10 non-null     str
# dtypes: int64(3), str(3)
# memory usage: 612.0 bytes

# %%
# Checking Missing Values
df.isnull().sum()
# Out:
# CustomerID    0
# Gender        0
# Age           0
# City          0
# Income        0
# Purchased     0
# dtype: int64

# %%
# Display Summary Statistics
df.describe()
# Out:
#        CustomerID        Age        Income
# count    10.00000  10.000000     10.000000
# mean      5.50000  32.400000  48400.000000
# std       3.02765   7.336363  11758.684734
# min       1.00000  22.000000  30000.000000
# 25%       3.25000  27.250000  39500.000000
# 50%       5.50000  31.500000  50000.000000
# 75%       7.75000  37.250000  57250.000000
# max      10.00000  45.000000  65000.000000

# %%
# Count Male and Female Customers
df["Gender"].value_counts()
# Out:
# Gender
# Male      5
# Female    5
# Name: count, dtype: int64

# %%
# Count Customers by City
df["City"].value_counts()
# Out:
# City
# Hyderabad    3
# Bengaluru    3
# Chennai      2
# Pune         2
# Name: count, dtype: int64

# %%
# Average Income
print(df["Income"].mean())
# Out:
# 48400.0

# %%
# Average Age
print(df["Age"].mean())
# Out:
# 32.4

# %%
# Highest Income
print(df["Income"].max())
# Out:
# 65000

# %%
# Lowest Income
print(df["Income"].min())
# Out:
# 30000

# %%
# Bar Chart
df["City"].value_counts().plot(kind="bar")

plt.title("Customers by City")

plt.xlabel("City")

plt.ylabel("Number of Customers")

plt.show()

# %%
# Pie chart
df["Gender"].value_counts().plot(kind="pie", autopct="%1.1f%%")

plt.title("Gender Distribution")

plt.show()

# %%
# Histogram
plt.hist(df["Age"])

plt.title("Age Distribution")

plt.xlabel("Age")

plt.ylabel("Frequency")

plt.show()
